# %%
import numpy as np # linear algebra
import pandas as pd 
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c646d3da-770c-44bf-86c5-e4ffe0737a3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c646d3da-770c-44bf-86c5-e4ffe0737a3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CarPrice_Assignment.csv to CarPrice_Assignment (5).csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['CarPrice_Assignment.csv']))

# %%
df
# Out:
#      car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0         1          3        alfa-romero giulia  ...      21         27  13495.0
# 1         2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2         3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3         4          2               audi 100 ls  ...      24         30  13950.0
# 4         5          2                audi 100ls  ...      18         22  17450.0
# ..      ...        ...                       ...  ...     ...        ...      ...
# 200     201         -1           volvo 145e (sw)  ...      23         28  16845.0
# 201     202         -1               volvo 144ea  ...      19         25  19045.0
# 202     203         -1               volvo 244dl  ...      18         23  21485.0
# 203     204         -1                 volvo 246  ...      26         27  22470.0
# 204     205         -1               volvo 264gl  ...      19         25  22625.0
#
# [205 rows x 26 columns]

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase  ...     citympg  highwaympg         price
# count  205.000000  205.000000  205.000000  ...  205.000000  205.000000    205.000000
# mean   103.000000    0.834146   98.756585  ...   25.219512   30.751220  13276.710571
# std     59.322565    1.245307    6.021776  ...    6.542142    6.886443   7988.852332
# min      1.000000   -2.000000   86.600000  ...   13.000000   16.000000   5118.000000
# 25%     52.000000    0.000000   94.500000  ...   19.000000   25.000000   7788.000000
# 50%    103.000000    1.000000   97.000000  ...   24.000000   30.000000  10295.000000
# 75%    154.000000    2.000000  102.400000  ...   30.000000   34.000000  16503.000000
# max    205.000000    3.000000  120.900000  ...   49.000000   54.000000  45400.000000
#
# [8 rows x 16 columns]

# %%
# drop outliers
df_drop_idx = df[(df['price']>30000) & (df['curbweight']<3000)].index
df.drop(df_drop_idx, axis=0)
# Out:
#      car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0         1          3        alfa-romero giulia  ...      21         27  13495.0
# 1         2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2         3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3         4          2               audi 100 ls  ...      24         30  13950.0
# 4         5          2                audi 100ls  ...      18         22  17450.0
# ..      ...        ...                       ...  ...     ...        ...      ...
# 200     201         -1           volvo 145e (sw)  ...      23         28  16845.0
# 201     202         -1               volvo 144ea  ...      19         25  19045.0
# 202     203         -1               volvo 244dl  ...      18         23  21485.0
# 203     204         -1                 volvo 246  ...      26         27  22470.0
# 204     205         -1               volvo 264gl  ...      19         25  22625.0
#
# [202 rows x 26 columns]

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase  ...     citympg  highwaympg         price
# count  205.000000  205.000000  205.000000  ...  205.000000  205.000000    205.000000
# mean   103.000000    0.834146   98.756585  ...   25.219512   30.751220  13276.710571
# std     59.322565    1.245307    6.021776  ...    6.542142    6.886443   7988.852332
# min      1.000000   -2.000000   86.600000  ...   13.000000   16.000000   5118.000000
# 25%     52.000000    0.000000   94.500000  ...   19.000000   25.000000   7788.000000
# 50%    103.000000    1.000000   97.000000  ...   24.000000   30.000000  10295.000000
# 75%    154.000000    2.000000  102.400000  ...   30.000000   34.000000  16503.000000
# max    205.000000    3.000000  120.900000  ...   49.000000   54.000000  45400.000000
#
# [8 rows x 16 columns]

# %%
# drop outliers
df_drop_idx = df[(df['price']>40000) & (df['horsepower']<200)].index
df.drop(df_drop_idx, axis=0)
# Out:
#      car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0         1          3        alfa-romero giulia  ...      21         27  13495.0
# 1         2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2         3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3         4          2               audi 100 ls  ...      24         30  13950.0
# 4         5          2                audi 100ls  ...      18         22  17450.0
# ..      ...        ...                       ...  ...     ...        ...      ...
# 200     201         -1           volvo 145e (sw)  ...      23         28  16845.0
# 201     202         -1               volvo 144ea  ...      19         25  19045.0
# 202     203         -1               volvo 244dl  ...      18         23  21485.0
# 203     204         -1                 volvo 246  ...      26         27  22470.0
# 204     205         -1               volvo 264gl  ...      19         25  22625.0
#
# [202 rows x 26 columns]

# %%
df_num_cols = df.select_dtypes(exclude = 'object')

# %%
df_str_cols = df.select_dtypes(include = 'object')

# %%
# make str columns to numerical columns using get_dummies
df_str_dummies = pd.get_dummies(df_str_cols, drop_first=True)

# %%
final_df = pd.concat([df_num_cols, df_str_dummies], axis=1)

# %%
final_df
# Out:
#      car_ID  symboling  ...  fuelsystem_spdi  fuelsystem_spfi
# 0         1          3  ...                0                0
# 1         2          3  ...                0                0
# 2         3          1  ...                0                0
# 3         4          2  ...                0                0
# 4         5          2  ...                0                0
# ..      ...        ...  ...              ...              ...
# 200     201         -1  ...                0                0
# 201     202         -1  ...                0                0
# 202     203         -1  ...                0                0
# 203     204         -1  ...                0                0
# 204     205         -1  ...                0                0
#
# [205 rows x 191 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x =final_df.drop('price', axis=1)
y= final_df['price']

# %%
x
# Out:
#      car_ID  symboling  ...  fuelsystem_spdi  fuelsystem_spfi
# 0         1          3  ...                0                0
# 1         2          3  ...                0                0
# 2         3          1  ...                0                0
# 3         4          2  ...                0                0
# 4         5          2  ...                0                0
# ..      ...        ...  ...              ...              ...
# 200     201         -1  ...                0                0
# 201     202         -1  ...                0                0
# 202     203         -1  ...                0                0
# 203     204         -1  ...                0                0
# 204     205         -1  ...                0                0
#
# [205 rows x 190 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor

# %%
X_train.shape
# Out:
# (114, 190)

# %%
model = Sequential()
model.add(Dense(512, input_dim=190, kernel_initializer='normal', activation='linear'))
model.add(Dense(256, activation='linear'))
model.add(Dense(128, activation='linear'))
model.add(Dense(1, activation='relu'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               97792
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 262,145
# Trainable params: 262,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# %%
history=model.fit(X_train, y_train, validation_data=(X_val,y_val),epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 72ms/step - loss: 150170563.4286 - mse: 150170563.4286 - val_loss: 104813680.0000 - val_mse: 104813680.0000
# Epoch 2/100
# 6/6 [==============================] - 0s 12ms/step - loss: 77423326.2857 - mse: 77423326.2857 - val_loss: 51978824.0000 - val_mse: 51978824.0000
# Epoch 3/100
# 6/6 [==============================] - 0s 13ms/step - loss: 51493219.7143 - mse: 51493219.7143 - val_loss: 42072192.0000 - val_mse: 42072192.0000
# Epoch 4/100
# 6/6 [==============================] - 0s 12ms/step - loss: 48134916.0000 - mse: 48134915.4286 - val_loss: 51957036.0000 - val_mse: 51957036.0000
# Epoch 5/100
# 6/6 [==============================] - 0s 13ms/step - loss: 48599691.4286 - mse: 48599691.4286 - val_loss: 33243110.0000 - val_mse: 33243110.0000
# Epoch 6/100
# 6/6 [==============================] - 0s 12ms/step - loss: 41321417.1429 - mse: 41321417.1429 - val_loss: 27746088.0000 - val_mse: 27746088.0000
# Epoch 7/100
# 6/6 [==============================] - 0s 15ms/step - loss: 38673769.1429 - mse: 38673769.1429 - val_loss: 26555900.0000 - val_mse: 26555900.0000
# Epoch 8/100
# 6/6 [==============================] - 0s 16ms/step - loss: 33106487.4286 - mse: 33106487.4286 - val_loss: 18274958.0000 - val_mse: 18274958.0000
# Epoch 9/100
# 6/6 [==============================] - 0s 16ms/step - loss: 36439722.0000 - mse: 36439720.2857 - val_loss: 17493974.0000 - val_mse: 17493974.0000
# Epoch 10/100
# 6/6 [==============================] - 0s 19ms/step - loss: 35988325.4286 - mse: 35988325.4286 - val_loss: 13009034.0000 - val_mse: 13009034.0000
# Epoch 11/100
# 6/6 [==============================] - 0s 16ms/step - loss: 23493431.0000 - mse: 23493431.0000 - val_loss: 14750415.0000 - val_mse: 14750415.0000
# Epoch 12/100
# 6/6 [==============================] - 0s 17ms/step - loss: 28255239.7143 - mse: 28255240.0000 - val_loss: 9530781.0000 - val_mse: 9530781.0000
# Epoch 13/100
# 6/6 [==============================] - 0s 16ms/step - loss: 28205734.8571 - mse: 28205734.8571 - val_loss: 10656577.0000 - val_mse: 10656577.0000
# Epoch 14/100
# 6/6 [==============================] - 0s 17ms/step - loss: 26146147.4286 - mse: 26146147.4286 - val_loss: 9709069.0000 - val_mse: 9709069.0000
# Epoch 15/100
# 6/6 [==============================] - 0s 16ms/step - loss: 25939711.7143 - mse: 25939711.7143 - val_loss: 10438198.0000 - val_mse: 10438198.0000
# Epoch 16/100
# 6/6 [==============================] - 0s 22ms/step - loss: 21777102.7143 - mse: 21777102.7143 - val_loss: 10249117.0000 - val_mse: 10249118.0000
# Epoch 17/100
# 6/6 [==============================] - 0s 18ms/step - loss: 25596859.4286 - mse: 25596859.4286 - val_loss: 9807773.0000 - val_mse: 9807773.0000
# Epoch 18/100
# 6/6 [==============================] - 0s 15ms/step - loss: 27542577.4286 - mse: 27542577.4286 - val_loss: 9339182.0000 - val_mse: 9339182.0000
# Epoch 19/100
# 6/6 [==============================] - 0s 18ms/step - loss: 35233446.5714 - mse: 35233446.5714 - val_loss: 8819083.0000 - val_mse: 8819084.0000
# Epoch 20/100
# 6/6 [==============================] - 0s 12ms/step - loss: 21496083.4286 - mse: 21496083.4286 - val_loss: 6597019.5000 - val_mse: 6597019.5000
# Epoch 97/100
# 6/6 [==============================] - 0s 12ms/step - loss: 12782225.4286 - mse: 12782225.4286 - val_loss: 6575365.5000 - val_mse: 6575365.5000
# Epoch 98/100
# 6/6 [==============================] - 0s 12ms/step - loss: 14765496.7143 - mse: 14765496.7143 - val_loss: 6473950.5000 - val_mse: 6473950.5000
# Epoch 99/100
# 6/6 [==============================] - 0s 14ms/step - loss: 15076369.0000 - mse: 15076369.0000 - val_loss: 5800831.5000 - val_mse: 5800831.5000
# Epoch 100/100
# 6/6 [==============================] - 0s 14ms/step - loss: 15447429.4286 - mse: 15447429.0000 - val_loss: 5722946.0000 - val_mse: 5722946.0000

# %%
import matplotlib.pyplot as plt
print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mse', 'val_loss', 'val_mse'])

# %%
final_df
# Out:
#      car_ID  symboling  ...  fuelsystem_spdi  fuelsystem_spfi
# 0         1          3  ...                0                0
# 1         2          3  ...                0                0
# 2         3          1  ...                0                0
# 3         4          2  ...                0                0
# 4         5          2  ...                0                0
# ..      ...        ...  ...              ...              ...
# 200     201         -1  ...                0                0
# 201     202         -1  ...                0                0
# 202     203         -1  ...                0                0
# 203     204         -1  ...                0                0
# 204     205         -1  ...                0                0
#
# [205 rows x 191 columns]

# %%
X_test.shape
# Out:
# (62, 190)

# %%
y_train.shape
# Out:
# (114,)

# %%
X_train.shape
# Out:
# (114, 190)

# %%
print("predictions on test data")
results = model.predict(X_test, batch_size=128)
print( results)
# Out:
# predictions on test data
# [[    0.    ]
#  [ 1910.7257]
#  [ 7761.849 ]
#  [    0.    ]
#  [15958.689 ]
#  [14040.43  ]
#  [ 8800.477 ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [12719.899 ]
#  [ 3441.931 ]
#  [    0.    ]
#  [    0.    ]
#  [ 3947.5205]
#  [    0.    ]
#  [  548.6752]
#  [ 9764.045 ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [10952.043 ]
#  [27858.74  ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [ 9124.76  ]
#  [    0.    ]
#  [    0.    ]
#  [17850.846 ]
#  [10573.426 ]
#  [16185.564 ]
#  [13956.498 ]
#  [    0.    ]
#  [    0.    ]
#  [  775.8932]
#  [ 1275.2184]
#  [    0.    ]
#  [    0.    ]
#  [31576.068 ]
#  [ 8064.1797]
#  [    0.    ]
#  [23887.9   ]
#  [    0.    ]
#  [    0.    ]
#  [ 1857.2247]
#  [18608.78  ]
#  [    0.    ]
#  [    0.    ]
#  [    0.    ]
#  [16165.682 ]
#  [23670.49  ]
#  [ 8030.53  ]
#  [ 3928.2947]
#  [11120.734 ]
#  [    0.    ]
#  [12218.582 ]
#  [ 1260.3615]
#  [    0.    ]]

# %%
results = model.evaluate(X_test, y_test, batch_size=128)
print("test loss, test acc:", results)
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 66997896.0000 - mse: 66997896.0000
# test loss, test acc: [66997896.0, 66997896.0]
